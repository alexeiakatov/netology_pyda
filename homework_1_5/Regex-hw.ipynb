# %% [markdown]
# # Домашнее задание к лекции "Регулярные выражения"
# Для зачета необходимо выполнить 4 задания.
# Для зачета с отличием – все.

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Напишите функцию, которая принимает на вход строку и проверяет является ли она валидным транспортным номером. Если да, то функция должна возвращать отдельно номер и регион.

# %%
import re

valid_car_numbers = ['е893хт59', 'у987вн177', 'е177кв26', 'о007оо77', 'а145нв147', 'т533ре123']

not_valid_car_numbers = (['те335хн123', '335хн123', 'т3кв123', 'т39кв123', 'т399квт123', 
                          'т399123', 'т399кв', 'т399кв1', 'т399кв3349', '_т399кв99а'])

car_number_validation_pattern = '^[авекмнорстху]{1}\d{3}[авекмнорстху]{2}\d{2,3}$'


def car_number_validator(car_number):
    car_number = car_number.lower().strip()
    result = re.search(car_number_validation_pattern, car_number)

    if result is not None:
        print(f'Валидный номер: {car_number}')
        return

    print(f'Не валидный номер: {car_number}')


for car_number in valid_car_numbers:
    car_number_validator(car_number)

print('*********')

for car_number in not_valid_car_numbers:
    car_number_validator(car_number)
# Out:
# Валидный номер: е893хт59
# Валидный номер: у987вн177
# Валидный номер: е177кв26
# Валидный номер: о007оо77
# Валидный номер: а145нв147
# Валидный номер: т533ре123
# *********
# Не валидный номер: те335хн123
# Не валидный номер: 335хн123
# Не валидный номер: т3кв123
# Не валидный номер: т39кв123
# Не валидный номер: т399квт123
# Не валидный номер: т399123
# Не валидный номер: т399кв
# Не валидный номер: т399кв1
# Не валидный номер: т399кв3349
# Не валидный номер: _т399кв99а

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Напишите функцию, которая проверяет e-mail адрес на валидность по стандарту RFC822: http://www.w3.org/Protocols/rfc822/. Для этого постарайтесь написать (в крайнем случае найти) самый полный шаблон для проверки e-mail адресов через регулярное выражение. Разберитесь и напишите примеры, какие ваш шаблон может не охватить.

# %%
# Выполненная задача находится в netology_pyda/homework_1_5/task_2
# Валидация делается сначала по отдельным regex-правилам, потом по составному правилу. 
# Так видно, что при общем правиле будут считаться валидными варианты где от @ до последней точки менее 4х символов.
# Проверка по отдельным правилам учитывает этот момент.
# tests.py - можно запустить тесты отдельных правил. На каждое правило есть по одному-несколько невалидных примеров. 
# Тесты это показывают.
# При запуске тестов желательно установить в main.py show_module_logs = False, иначе на каждый тестовый пример
# будет сообщение о причине невалидности примера.

# %% [markdown]
# ## Задание 3
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки.

# %% [markdown]
# ## Задание 4
# Напишите функцию, которая будет проверять номер сотового телефона на валидность, если он валиден, то переводить его в формат:
# +7(xxx)-xxx-xx-xx
# Постарайтесь предусмотреть как можно больше адекватных форматов изначального ввода номера.
# Примеры правильных и неправильных форматов:
# - +7 955 555-55-55;
# - 955555555;
# - 8(955)555-55-55;
# - +7 955 555 55 55;
# - 7(955) 555-55-55;
# - +7 955+555+55+55.
